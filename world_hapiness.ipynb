# %% [markdown]
# <a href="https://colab.research.google.com/github/rifflere/CS108-example/blob/main/world_hapiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # World Happpiness
# Rebecca Riffle
# CS 108: Data Science

# %% [markdown]
# Intro
# This text...

# %% [markdown]
# # Questions
#
#
# 1.   According to most recent data, what country is the happiest?
# 2.   Which is a better correlation with happiness - wealth or social connectivity?
# 3. Is the world getting progressively more or less happy?
# 4. Did countries with higher GDPs report more or less generosity than countries with lower GDPs?

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/myFunctions.py"

# %%
#Import libraries
from re import escape
import matplotlib.pyplot as plt


'''
Author: Rebecca Riffle
Date: 10/28/2024
'''

# Display title
print(":) " * 7)
# printTitle("World Happiness Report")
# printIntro()

# questionNumber = getInput()

# Which of these identified factors most closely correlates to happiness?
# Are wealthier countries happier?
# Is the world getting progressively more or less happy overall?


# Prompt user for input here
inputyear = int(input("Enter a year between 2007 and 2023: "))
# Validate input

# Open and read datafile
textFile = open("/content/drive/MyDrive/Colab Notebooks/World Hapiness Report/dataCSV.csv", encoding="utf-8")
dataRows = textFile.readlines()[1:]

print("The Life Ladder is a representation life of 0-10, where 0 is the worst possible life, and 10 is the best.")

# Process each row
for row in dataRows:

    # Prepare and store data
    row = row.strip()
    values = row.split(",")

    # # CHOOSE WHICH ONES ARE RELEVANT TO KEEP
    country = values[0]
    year = values[1]
    lifeLadder = values[2]
    gDP = values[3]
    socialSupport = values[4]
    lifeExpectancy = values[5]
    Freedom = values[6]
    Generosity = values[7]
    corruption = values[8]
    positiveAffect = values[9]
    negativeAffect = values[10]

    # Convert numbers
    year = int(year)
    lifeLadder = float(lifeLadder)
    # socialSupport = float(socialSupport)
    # lifeExpectancy = float(lifeExpectancy)
    # Freedom = float(Freedom)
    # Generosity = float(Generosity)
    # corruption = float(corruption)

    # Add emoji to lifeladder
    if lifeLadder >= 8:
        lifeLadderEmoji = ":D !"
    elif lifeLadder >= 6:
        lifeLadderEmoji = ":)"
    elif lifeLadder >= 4:
        lifeLadderEmoji = ":|"
    elif lifeLadder >= 2:
        lifeLadderEmoji = ":("
    else:
        lifeLadderEmoji = ""

    # Add dollar signs to GDP
    if gDP != "":
            gDP = float(gDP)
            if gDP >= 10.5:
                gDPDollars = "$$$$"
            elif gDP >= 8:
                gDPDollars = "$$$"
            elif gDP >= 6:
                gDPDollars = "$$"
            elif gDP >= 3:
                gDPDollars = "$"
            else:
                gDPDollars = ""
    else:
        gDP = "Unknown"
        gDPDollars = ""

    # Condition
    if inputyear == year:

        # Display data
        print("Country:",country)
        print("Year:",year)
        print("Life Ladder (0 - 10):",lifeLadder,lifeLadderEmoji)
        print("GDP Per Capita (international dollars):",gDP,gDPDollars)
        print("Social Support:",socialSupport)
        print("Life Expectancy:",lifeExpectancy)
        print("Freedom:",Freedom)
        print("Generosity:",Generosity)
        print("Corruption:",corruption)
        print()
# Out:
# :) :) :) :) :) :) :)
# Enter a year between 2007 and 2023: 2008
# The Life Ladder is a representation life of 0-10, where 0 is the worst possible life, and 10 is the best.
# Country: Afghanistan
# Year: 2008
# Life Ladder (0 - 10): 3.724 :(
# GDP Per Capita (international dollars): 7.35 $$
# Social Support: 0.451
# Life Expectancy: 50.500
# Freedom: 0.718
# Generosity: 0.164
# Corruption: 0.882
#
# Country: Argentina
# Year: 2008
# Life Ladder (0 - 10): 5.961 :|
# GDP Per Capita (international dollars): 10.043 $$$
# Social Support: 0.892
# Life Expectancy: 66.060
# Freedom: 0.678
# Generosity: -0.137
# Corruption: 0.865
#
# Country: Armenia
# Year: 2008
# Life Ladder (0 - 10): 4.652 :|
# GDP Per Capita (international dollars): 9.23 $$$
# Social Support: 0.709
# Life Expectancy: 64.320
# Freedom: 0.462
# Generosity: -0.219
# Corruption: 0.876
#
# Country: Australia
# Year: 2008
# Life Ladder (0 - 10): 7.254 :)
# GDP Per Capita (international dollars): 10.709 $$$$
# Social Support: 0.947
# Life Expectancy: 70.040
# Freedom: 0.916
# Generosity: 0.300
# Corruption: 0.431
#
# Country: Austria
# Year: 2008
# Life Ladder (0 - 10): 7.181 :)
# GDP Per Capita (international dollars): 10.881 $$$$
# Social Support: 0.935
# Life Expectancy: 69.700
# Freedom: 0.879
# Generosity: 0.286
# Corruption: 0.614
#
# Country: Azerbaijan
# Year: 2008
# Life Ladder (0 - 10): 4.817 :|
# GDP Per Capita (international dollars): 9.447 $$$
# Social Support: 0.684
# Life Expectancy: 61.140
# Freedom: 0.601
# Generosity: -0.034
# Corruption: 0.715
#
# Country: Bangladesh
# Year: 2008
# Life Ladder (0 - 10): 5.052 :|
# GDP Per Capita (international dollars): 8.047 $$$
# Social Support: 0.467
# Life Expectancy: 60.160
# Freedom: 0.606
# Generosity: -0.060
# Corruption: 0.802
#
# Country: Belarus
# Year: 2008
# Life Ladder (0 - 10): 5.463 :|
# GDP Per Capita (international dollars): 9.677 $$$
# Social Support: 0.904
# Life Expectancy: 61.180
# Freedom: 0.640
# Generosity: -0.226
# Corruption: 0.696
#
# Country: Belgium
# Year: 2008
# Life Ladder (0 - 10): 7.117 :)
# GDP Per Capita (international dollars): 10.788 $$$$
# Social Support: 0.923
# Life Expectancy: 68.880
# Freedom: 0.887
# Generosity: 0.001
# Corruption: 0.652
#
# Country: Benin
# Year: 2008
# Life Ladder (0 - 10): 3.667 :(
# GDP Per Capita (international dollars): 7.891 $$
# Social Support: 0.382
# Life Expectancy: 52.480
# Freedom: 0.709
# Generosity: -0.008
# Corruption: 0.825
#
# Country: Bolivia
# Year: 2008
# Life Ladder (0 - 10): 5.298 :|
# GDP Per Capita (international dollars): 8.74 $$$
# Social Support: 0.785
# Life Expectancy: 61.300
# Freedom: 0.726
# Generosity: -0.096
# Corruption: 0.801
#
# Country: Botswana
# Year: 2008
# Life Ladder (0 - 10): 5.451 :|
# GDP Per Capita (international dollars): 9.543 $$$
# Social Support: 0.832
# Life Expectancy: 49.720
# Freedom: 0.858
# Generosity: -0.167
# Corruption: 0.806
#
# Country: Brazil
# Year: 2008
# Life Ladder (0 - 10): 6.691 :)
# GDP Per Capita (international dollars): 9.552 $$$
# Social Support: 0.878
# Life Expectancy: 63.580
# Freedom: 0.782
# Generosity: -0.083
# Corruption: 0.688
#
# Country: Burkina Faso
# Year: 2008
# Life Ladder (0 - 10): 3.846 :(
# GDP Per Capita (international dollars): 7.364 $$
# Social Support: 0.727
# Life Expectancy: 50.320
# Freedom: 0.612
# Generosity: -0.103
# Corruption: 0.887
#
# Country: Burundi
# Year: 2008
# Life Ladder (0 - 10): 3.563 :(
# GDP Per Capita (international dollars): 6.7 $$
# Social Support: 0.291
# Life Expectancy: 49.660
# Freedom: 0.260
# Generosity: -0.022
# Corruption: 0.860
#
# Country: Cambodia
# Year: 2008
# Life Ladder (0 - 10): 4.462 :|
# GDP Per Capita (international dollars): 7.874 $$
# Social Support: 0.619
# Life Expectancy: 58.320
# Freedom: 0.914
# Generosity: 0.041
# Corruption: 0.888
#
# Country: Cameroon
# Year: 2008
# Life Ladder (0 - 10): 4.292 :|
# GDP Per Capita (international dollars): 8.104 $$$
# Social Support: 0.697
# Life Expectancy: 48.720
# Freedom: 0.580
# Generosity: -0.079
# Corruption: 0.945
#
# Country: Canada
# Year: 2008
# Life Ladder (0 - 10): 7.486 :)
# GDP Per Capita (international dollars): 10.733 $$$$
# Social Support: 0.939
# Life Expectancy: 70.680
# Freedom: 0.926
# Generosity: 0.256
# Corruption: 0.370
#
# Country: Chad
# Year: 2008
# Life Ladder (0 - 10): 4.632 :|
# GDP Per Capita (international dollars): 7.363 $$
# Social Support: 0.571
# Life Expectancy: 47.840
# Freedom: 0.527
# Generosity: 0.057
# Corruption: 0.944
#
# Country: Chile
# Year: 2008
# Life Ladder (0 - 10): 5.789 :|
# GDP Per Capita (international dollars): 9.938 $$$
# Social Support: 0.804
# Life Expectancy: 68.140
# Freedom: 0.640
# Generosity: 0.076
# Corruption: 0.741
#
# Country: China
# Year: 2008
# Life Ladder (0 - 10): 4.846 :|
# GDP Per Capita (international dollars): 8.911 $$$
# Social Support: 0.748
# Life Expectancy: 66.180
# Freedom: 0.853
# Generosity: -0.098
# Corruption:
#
# Country: Colombia
# Year: 2008
# Life Ladder (0 - 10): 6.168 :)
# GDP Per Capita (international dollars): 9.351 $$$
# Social Support: 0.880
# Life Expectancy: 66.760
# Freedom: 0.795
# Generosity: -0.047
# Corruption: 0.763
#
# Country: Congo (Brazzaville)
# Year: 2008
# Life Ladder (0 - 10): 3.82 :(
# GDP Per Capita (international dollars): 8.39 $$$
# Social Support: 0.555
# Life Expectancy: 52.240
# Freedom: 0.526
# Generosity: -0.125
# Corruption:
#
# Country: Costa Rica
# Year: 2008
# Life Ladder (0 - 10): 6.851 :)
# GDP Per Capita (international dollars): 9.704 $$$
# Social Support: 0.916
# Life Expectancy: 68.880
# Freedom: 0.912
# Generosity: 0.087
# Corruption: 0.816
#
# Country: Denmark
# Year: 2008
# Life Ladder (0 - 10): 7.971 :)
# GDP Per Capita (international dollars): 10.878 $$$$
# Social Support: 0.954
# Life Expectancy: 68.960
# Freedom: 0.970
# Generosity: 0.266
# Corruption: 0.248
#
# Country: Djibouti
# Year: 2008
# Life Ladder (0 - 10): 5.009 :|
# GDP Per Capita (international dollars): 8.115 $$$
# Social Support: 0.690
# Life Expectancy: 53.640
# Freedom: 0.773
# Generosity: 0.123
# Corruption: 0.576
#
# Country: Dominican Republic
# Year: 2008
# Life Ladder (0 - 10): 4.842 :|
# GDP Per Capita (international dollars): 9.384 $$$
# Social Support: 0.850
# Life Expectancy: 64.880
# Freedom: 0.848
# Generosity: -0.050
# Corruption: 0.728
#
# Country: Ecuador
# Year: 2008
# Life Ladder (0 - 10): 5.297 :|
# GDP Per Capita (international dollars): 9.238 $$$
# Social Support: 0.829
# Life Expectancy: 65.120
# Freedom: 0.640
# Generosity: -0.100
# Corruption: 0.801
#
# Country: Egypt
# Year: 2008
# Life Ladder (0 - 10): 4.632 :|
# GDP Per Capita (international dollars): 9.187 $$$
# Social Support: 0.738
# Life Expectancy: 61.580
# Freedom:
# Generosity: -0.093
# Corruption: 0.914
#
# Country: El Salvador
# Year: 2008
# Life Ladder (0 - 10): 5.191 :|
# GDP Per Capita (international dollars): 8.919 $$$
# Social Support: 0.747
# Life Expectancy: 64.760
# Freedom: 0.636
# Generosity: -0.084
# Corruption: 0.735
#
# Country: Estonia
# Year: 2008
# Life Ladder (0 - 10): 5.452 :|
# GDP Per Capita (international dollars): 10.296 $$$
# Social Support: 0.904
# Life Expectancy: 66.340
# Freedom: 0.642
# Generosity: -0.223
# Corruption: 0.663
#
# Country: Finland
# Year: 2008
# Life Ladder (0 - 10): 7.671 :)
# GDP Per Capita (international dollars): 10.796 $$$$
# Social Support: 0.951
# Life Expectancy: 69.160
# Freedom: 0.934
# Generosity: 0.022
# Corruption: 0.217
#
# Country: France
# Year: 2008
# Life Ladder (0 - 10): 7.008 :)
# GDP Per Capita (international dollars): 10.669 $$$$
# Social Support: 0.935
# Life Expectancy: 71.000
# Freedom: 0.833
# Generosity: -0.037
# Corruption: 0.669
#
# Country: Georgia
# Year: 2008
# Life Ladder (0 - 10): 4.156 :|
# GDP Per Capita (international dollars): 9.144 $$$
# Social Support: 0.608
# Life Expectancy: 63.500
# Freedom: 0.614
# Generosity: -0.230
# Corruption: 0.498
#
# Country: Germany
# Year: 2008
# Life Ladder (0 - 10): 6.522 :)
# GDP Per Capita (international dollars): 10.771 $$$$
# Social Support: 0.923
# Life Expectancy: 69.960
# Freedom: 0.766
# Generosity:
# Corruption: 0.758
#
# Country: Ghana
# Year: 2008
# Life Ladder (0 - 10): 4.965 :|
# GDP Per Capita (international dollars): 8.145 $$$
# Social Support: 0.622
# Life Expectancy: 53.420
# Freedom: 0.838
# Generosity: 0.115
# Corruption: 0.863
#
# Country: Guatemala
# Year: 2008
# Life Ladder (0 - 10): 6.414 :)
# GDP Per Capita (international dollars): 8.905 $$$
# Social Support: 0.866
# Life Expectancy: 59.540
# Freedom: 0.630
# Generosity: 0.200
# Corruption: 0.796
#
# Country: Haiti
# Year: 2008
# Life Ladder (0 - 10): 3.846 :(
# GDP Per Capita (international dollars): 8.016 $$$
# Social Support: 0.679
# Life Expectancy: 17.360
# Freedom: 0.465
# Generosity: 0.213
# Corruption: 0.812
#
# Country: Honduras
# Year: 2008
# Life Ladder (0 - 10): 5.42 :|
# GDP Per Capita (international dollars): 8.504 $$$
# Social Support: 0.828
# Life Expectancy: 62.700
# Freedom: 0.687
# Generosity: 0.219
# Corruption: 0.863
#
# Country: Hong Kong S.A.R. of China
# Year: 2008
# Life Ladder (0 - 10): 5.137 :|
# GDP Per Capita (international dollars): 10.816 $$$$
# Social Support: 0.840
# Life Expectancy:
# Freedom: 0.922
# Generosity: 0.290
# Corruption: 0.274
#
# Country: Iceland
# Year: 2008
# Life Ladder (0 - 10): 6.888 :)
# GDP Per Capita (international dollars): 10.878 $$$$
# Social Support: 0.977
# Life Expectancy: 71.200
# Freedom: 0.885
# Generosity: 0.265
# Corruption: 0.708
#
# Country: India
# Year: 2008
# Life Ladder (0 - 10): 5.146 :|
# GDP Per Capita (international dollars): 8.216 $$$
# Social Support: 0.684
# Life Expectancy: 56.580
# Freedom: 0.756
# Generosity: -0.077
# Corruption: 0.891
#
# Country: Indonesia
# Year: 2008
# Life Ladder (0 - 10): 4.815 :|
# GDP Per Capita (international dollars): 8.933 $$$
# Social Support: 0.675
# Life Expectancy: 60.760
# Freedom: 0.596
# Generosity: 0.160
# Corruption: 0.968
#
# Country: Iran
# Year: 2008
# Life Ladder (0 - 10): 5.129 :|
# GDP Per Capita (international dollars): 9.584 $$$
# Social Support: 0.633
# Life Expectancy: 64.720
# Freedom: 0.601
# Generosity: 0.040
# Corruption: 0.868
#
# Country: Iraq
# Year: 2008
# Life Ladder (0 - 10): 4.59 :|
# GDP Per Capita (international dollars): 8.982 $$$
# Social Support: 0.744
# Life Expectancy: 60.940
# Freedom: 0.386
# Generosity: -0.061
# Corruption: 0.910
#
# Country: Ireland
# Year: 2008
# Life Ladder (0 - 10): 7.568 :)
# GDP Per Capita (international dollars): 10.941 $$$$
# Social Support: 0.983
# Life Expectancy: 69.860
# Freedom: 0.894
# Generosity: 0.315
# Corruption: 0.487
#
# Country: Israel
# Year: 2008
# Life Ladder (0 - 10): 7.261 :)
# GDP Per Capita (international dollars): 10.423 $$$
# Social Support: 0.859
# Life Expectancy: 71.240
# Freedom: 0.663
# Generosity: 0.134
# Corruption: 0.898
#
# Country: Italy
# Year: 2008
# Life Ladder (0 - 10): 6.78 :)
# GDP Per Capita (international dollars): 10.706 $$$$
# Social Support: 0.880
# Life Expectancy: 70.900
# Freedom: 0.543
# Generosity: 0.044
# Corruption: 0.946
#
# Country: Japan
# Year: 2008
# Life Ladder (0 - 10): 5.911 :|
# GDP Per Capita (international dollars): 10.566 $$$$
# Social Support: 0.887
# Life Expectancy: 72.760
# Freedom: 0.772
# Generosity: -0.142
# Corruption: 0.816
#
# Country: Jordan
# Year: 2008
# Life Ladder (0 - 10): 4.93 :|
# GDP Per Capita (international dollars): 9.354 $$$
# Social Support: 0.766
# Life Expectancy: 66.340
# Freedom:
# Generosity: -0.134
# Corruption: 0.709
#
# Country: Kazakhstan
# Year: 2008
# Life Ladder (0 - 10): 5.886 :|
# GDP Per Capita (international dollars): 9.892 $$$
# Social Support: 0.839
# Life Expectancy: 59.200
# Freedom: 0.727
# Generosity: -0.226
# Corruption: 0.899
#
# Country: Kenya
# Year: 2008
# Life Ladder (0 - 10): 4.015 :|
# GDP Per Capita (international dollars): 8.173 $$$
# Social Support: 0.827
# Life Expectancy: 52.460
# Freedom: 0.620
# Generosity: -0.026
# Corruption: 0.909
#
# Country: Kosovo
# Year: 2008
# Life Ladder (0 - 10): 5.522 :|
# GDP Per Capita (international dollars): 8.858 $$$
# Social Support: 0.884
# Life Expectancy:
# Freedom:
# Generosity: 0.094
# Corruption: 0.849
#
# Country: Kyrgyzstan
# Year: 2008
# Life Ladder (0 - 10): 4.737 :|
# GDP Per Capita (international dollars): 8.329 $$$
# Social Support: 0.792
# Life Expectancy: 60.760
# Freedom: 0.719
# Generosity: -0.105
# Corruption: 0.923
#
# Country: Laos
# Year: 2008
# Life Ladder (0 - 10): 5.044 :|
# GDP Per Capita (international dollars): 8.351 $$$
# Social Support: 0.807
# Life Expectancy: 56.640
# Freedom: 0.886
# Generosity: 0.412
# Corruption: 0.637
#
# Country: Latvia
# Year: 2008
# Life Ladder (0 - 10): 5.145 :|
# GDP Per Capita (international dollars): 10.123 $$$
# Social Support: 0.855
# Life Expectancy: 63.700
# Freedom: 0.630
# Generosity: -0.210
# Corruption: 0.926
#
# Country: Lebanon
# Year: 2008
# Life Ladder (0 - 10): 4.595 :|
# GDP Per Capita (international dollars): 9.711 $$$
# Social Support: 0.717
# Life Expectancy: 65.280
# Freedom: 0.524
# Generosity: 0.031
# Corruption: 0.927
#
# Country: Liberia
# Year: 2008
# Life Ladder (0 - 10): 4.221 :|
# GDP Per Capita (international dollars): 7.207 $$
# Social Support: 0.619
# Life Expectancy: 51.940
# Freedom: 0.724
# Generosity: -0.038
# Corruption: 0.840
#
# Country: Lithuania
# Year: 2008
# Life Ladder (0 - 10): 5.554 :|
# GDP Per Capita (international dollars): 10.196 $$$
# Social Support: 0.914
# Life Expectancy: 63.900
# Freedom: 0.621
# Generosity: -0.265
# Corruption: 0.961
#
# Country: Madagascar
# Year: 2008
# Life Ladder (0 - 10): 4.64 :|
# GDP Per Capita (international dollars): 7.413 $$
# Social Support: 0.776
# Life Expectancy: 54.620
# Freedom: 0.332
# Generosity: -0.103
# Corruption: 0.773
#
# Country: Malaysia
# Year: 2008
# Life Ladder (0 - 10): 5.807 :|
# GDP Per Capita (international dollars): 9.893 $$$
# Social Support: 0.803
# Life Expectancy: 65.240
# Freedom: 0.780
# Generosity: 0.040
# Corruption: 0.884
#
# Country: Mali
# Year: 2008
# Life Ladder (0 - 10): 4.115 :|
# GDP Per Capita (international dollars): 7.576 $$
# Social Support: 0.747
# Life Expectancy: 50.620
# Freedom: 0.495
# Generosity: -0.015
# Corruption: 0.918
#
# Country: Mauritania
# Year: 2008
# Life Ladder (0 - 10): 4.248 :|
# GDP Per Capita (international dollars): 8.5 $$$
# Social Support: 0.670
# Life Expectancy: 56.800
# Freedom: 0.593
# Generosity: -0.023
# Corruption: 0.841
#
# Country: Mexico
# Year: 2008
# Life Ladder (0 - 10): 6.829 :)
# GDP Per Capita (international dollars): 9.83 $$$
# Social Support: 0.876
# Life Expectancy: 64.820
# Freedom: 0.677
# Generosity: -0.134
# Corruption: 0.785
#
# Country: Moldova
# Year: 2008
# Life Ladder (0 - 10): 5.503 :|
# GDP Per Capita (international dollars): 9.031 $$$
# Social Support: 0.872
# Life Expectancy: 60.240
# Freedom: 0.641
# Generosity: -0.060
# Corruption: 0.926
#
# Country: Mongolia
# Year: 2008
# Life Ladder (0 - 10): 4.493 :|
# GDP Per Capita (international dollars): 8.902 $$$
# Social Support: 0.920
# Life Expectancy: 56.960
# Freedom: 0.484
# Generosity: 0.062
# Corruption: 0.962
#
# Country: Mozambique
# Year: 2008
# Life Ladder (0 - 10): 4.654 :|
# GDP Per Capita (international dollars): 6.885 $$
# Social Support: 0.756
# Life Expectancy: 45.660
# Freedom: 0.514
# Generosity: 0.000
# Corruption: 0.864
#
# Country: Nepal
# Year: 2008
# Life Ladder (0 - 10): 4.441 :|
# GDP Per Capita (international dollars): 7.814 $$
# Social Support: 0.818
# Life Expectancy: 59.780
# Freedom: 0.618
# Generosity: 0.276
# Corruption: 0.900
#
# Country: Netherlands
# Year: 2008
# Life Ladder (0 - 10): 7.631 :)
# GDP Per Capita (international dollars): 10.894 $$$$
# Social Support: 0.944
# Life Expectancy: 70.820
# Freedom: 0.883
# Generosity: 0.359
# Corruption: 0.419
#
# Country: New Zealand
# Year: 2008
# Life Ladder (0 - 10): 7.381 :)
# GDP Per Capita (international dollars): 10.541 $$$$
# Social Support: 0.944
# Life Expectancy: 69.760
# Freedom: 0.893
# Generosity: 0.291
# Corruption: 0.334
#
# Country: Nicaragua
# Year: 2008
# Life Ladder (0 - 10): 5.104 :|
# GDP Per Capita (international dollars): 8.45 $$$
# Social Support: 0.857
# Life Expectancy: 64.500
# Freedom: 0.791
# Generosity: 0.070
# Corruption: 0.819
#
# Country: Niger
# Year: 2008
# Life Ladder (0 - 10): 4.236 :|
# GDP Per Capita (international dollars): 6.905 $$
# Social Support: 0.607
# Life Expectancy: 51.020
# Freedom: 0.649
# Generosity: -0.059
# Corruption: 0.749
#
# Country: Nigeria
# Year: 2008
# Life Ladder (0 - 10): 4.939 :|
# GDP Per Capita (international dollars): 8.389 $$$
# Social Support: 0.780
# Life Expectancy: 50.860
# Freedom: 0.584
# Generosity: 0.115
# Corruption: 0.892
#
# Country: Norway
# Year: 2008
# Life Ladder (0 - 10): 7.632 :)
# GDP Per Capita (international dollars): 11.066 $$$$
# Social Support: 0.936
# Life Expectancy: 69.800
# Freedom: 0.947
# Generosity: 0.010
# Corruption: 0.503
#
# Country: Pakistan
# Year: 2008
# Life Ladder (0 - 10): 4.414 :|
# GDP Per Capita (international dollars): 8.309 $$$
# Social Support: 0.373
# Life Expectancy: 53.980
# Freedom: 0.335
# Generosity: 0.092
# Corruption: 0.848
#
# Country: Panama
# Year: 2008
# Life Ladder (0 - 10): 6.931 :)
# GDP Per Capita (international dollars): 9.977 $$$
# Social Support: 0.922
# Life Expectancy: 67.180
# Freedom: 0.707
# Generosity: 0.051
# Corruption: 0.881
#
# Country: Paraguay
# Year: 2008
# Life Ladder (0 - 10): 5.57 :|
# GDP Per Capita (international dollars): 9.25 $$$
# Social Support: 0.889
# Life Expectancy: 65.040
# Freedom: 0.649
# Generosity: 0.046
# Corruption: 0.891
#
# Country: Peru
# Year: 2008
# Life Ladder (0 - 10): 5.129 :|
# GDP Per Capita (international dollars): 9.134 $$$
# Social Support: 0.777
# Life Expectancy: 66.980
# Freedom: 0.638
# Generosity: -0.072
# Corruption: 0.896
#
# Country: Philippines
# Year: 2008
# Life Ladder (0 - 10): 4.589 :|
# GDP Per Capita (international dollars): 8.63 $$$
# Social Support: 0.798
# Life Expectancy: 61.480
# Freedom: 0.861
# Generosity: 0.078
# Corruption: 0.817
#
# Country: Portugal
# Year: 2008
# Life Ladder (0 - 10): 5.717 :|
# GDP Per Capita (international dollars): 10.383 $$$
# Social Support: 0.886
# Life Expectancy: 68.820
# Freedom: 0.646
# Generosity: -0.223
# Corruption: 0.933
#
# Country: Russia
# Year: 2008
# Life Ladder (0 - 10): 5.619 :|
# GDP Per Capita (international dollars): 10.122 $$$
# Social Support: 0.882
# Life Expectancy: 59.620
# Freedom: 0.643
# Generosity: -0.311
# Corruption: 0.924
#
# Country: Rwanda
# Year: 2008
# Life Ladder (0 - 10): 4.363 :|
# GDP Per Capita (international dollars): 7.213 $$
# Social Support: 0.486
# Life Expectancy: 54.700
# Freedom: 0.752
# Generosity: 0.014
# Corruption: 0.286
#
# Country: Saudi Arabia
# Year: 2008
# Life Ladder (0 - 10): 6.811 :)
# GDP Per Capita (international dollars): 10.668 $$$$
# Social Support: 0.823
# Life Expectancy: 61.800
# Freedom: 0.532
# Generosity: -0.024
# Corruption: 0.508
#
# Country: Senegal
# Year: 2008
# Life Ladder (0 - 10): 4.683 :|
# GDP Per Capita (international dollars): 7.941 $$
# Social Support: 0.756
# Life Expectancy: 56.100
# Freedom: 0.612
# Generosity: -0.037
# Corruption: 0.879
#
# Country: Sierra Leone
# Year: 2008
# Life Ladder (0 - 10): 2.997 :(
# GDP Per Capita (international dollars): 7.205 $$
# Social Support: 0.591
# Life Expectancy: 47.040
# Freedom: 0.716
# Generosity: 0.144
# Corruption: 0.925
#
# Country: Singapore
# Year: 2008
# Life Ladder (0 - 10): 6.642 :)
# GDP Per Capita (international dollars): 11.178 $$$$
# Social Support: 0.845
# Life Expectancy: 71.940
# Freedom: 0.661
# Generosity: 0.040
# Corruption: 0.066
#
# Country: South Africa
# Year: 2008
# Life Ladder (0 - 10): 5.346 :|
# GDP Per Capita (international dollars): 9.518 $$$
# Social Support: 0.810
# Life Expectancy: 47.800
# Freedom: 0.749
# Generosity: -0.106
# Corruption: 0.866
#
# Country: South Korea
# Year: 2008
# Life Ladder (0 - 10): 5.39 :|
# GDP Per Capita (international dollars): 10.382 $$$
# Social Support: 0.754
# Life Expectancy: 70.460
# Freedom: 0.524
# Generosity: -0.108
# Corruption: 0.771
#
# Country: Spain
# Year: 2008
# Life Ladder (0 - 10): 7.294 :)
# GDP Per Capita (international dollars): 10.577 $$$$
# Social Support: 0.948
# Life Expectancy: 70.760
# Freedom: 0.834
# Generosity: -0.155
# Corruption: 0.683
#
# Country: Sri Lanka
# Year: 2008
# Life Ladder (0 - 10): 4.431 :|
# GDP Per Capita (international dollars): 9.04 $$$
# Social Support: 0.816
# Life Expectancy: 63.240
# Freedom: 0.834
# Generosity: 0.156
# Corruption: 0.861
#
# Country: State of Palestine
# Year: 2008
# Life Ladder (0 - 10): 4.386 :|
# GDP Per Capita (international dollars): 8.275 $$$
# Social Support: 0.666
# Life Expectancy:
# Freedom: 0.358
# Generosity: -0.075
# Corruption: 0.753
#
# Country: Sweden
# Year: 2008
# Life Ladder (0 - 10): 7.516 :)
# GDP Per Capita (international dollars): 10.778 $$$$
# Social Support: 0.923
# Life Expectancy: 71.120
# Freedom: 0.912
# Generosity: 0.120
# Corruption: 0.314
#
# Country: Syria
# Year: 2008
# Life Ladder (0 - 10): 5.323 :|
# GDP Per Capita (international dollars): 8.658 $$$
# Social Support: 0.712
# Life Expectancy: 68.620
# Freedom: 0.661
# Generosity: 0.116
# Corruption: 0.680
#
# Country: Taiwan Province of China
# Year: 2008
# Life Ladder (0 - 10): 5.548 :|
# GDP Per Capita (international dollars): 10.6 $$$$
# Social Support: 0.830
# Life Expectancy: 69.140
# Freedom: 0.642
# Generosity: -0.022
# Corruption: 0.785
#
# Country: Tajikistan
# Year: 2008
# Life Ladder (0 - 10): 5.064 :|
# GDP Per Capita (international dollars): 7.705 $$
# Social Support: 0.701
# Life Expectancy: 60.700
# Freedom: 0.816
# Generosity: 0.010
# Corruption: 0.723
#
# Country: Tanzania
# Year: 2008
# Life Ladder (0 - 10): 4.385 :|
# GDP Per Capita (international dollars): 7.525 $$
# Social Support: 0.774
# Life Expectancy: 52.080
# Freedom: 0.562
# Generosity: 0.253
# Corruption: 0.930
#
# Country: Thailand
# Year: 2008
# Life Ladder (0 - 10): 5.636 :|
# GDP Per Capita (international dollars): 9.507 $$$
# Social Support: 0.832
# Life Expectancy: 66.740
# Freedom: 0.868
# Generosity: 0.421
# Corruption: 0.933
#
# Country: Togo
# Year: 2008
# Life Ladder (0 - 10): 2.808 :(
# GDP Per Capita (international dollars): 7.312 $$
# Social Support: 0.291
# Life Expectancy: 51.120
# Freedom: 0.287
# Generosity: -0.078
# Corruption: 0.932
#
# Country: Trinidad and Tobago
# Year: 2008
# Life Ladder (0 - 10): 6.696 :)
# GDP Per Capita (international dollars): 10.24 $$$
# Social Support: 0.858
# Life Expectancy: 62.540
# Freedom: 0.838
# Generosity: 0.085
# Corruption: 0.959
#
# Country: T rkiye
# Year: 2008
# Life Ladder (0 - 10): 5.118 :|
# GDP Per Capita (international dollars): 9.887 $$$
# Social Support: 0.645
# Life Expectancy: 66.580
# Freedom: 0.415
# Generosity: -0.194
# Corruption: 0.785
#
# Country: Uganda
# Year: 2008
# Life Ladder (0 - 10): 4.569 :|
# GDP Per Capita (international dollars): 7.476 $$
# Social Support: 0.813
# Life Expectancy: 50.420
# Freedom: 0.578
# Generosity: -0.060
# Corruption: 0.848
#
# Country: Ukraine
# Year: 2008
# Life Ladder (0 - 10): 5.172 :|
# GDP Per Capita (international dollars): 9.527 $$$
# Social Support: 0.860
# Life Expectancy: 61.560
# Freedom: 0.487
# Generosity: -0.273
# Corruption: 0.929
#
# Country: United Kingdom
# Year: 2008
# Life Ladder (0 - 10): 6.986 :)
# GDP Per Capita (international dollars): 10.684 $$$$
# Social Support: 0.954
# Life Expectancy: 69.280
# Freedom: 0.759
# Generosity: 0.325
# Corruption: 0.548
#
# Country: United States
# Year: 2008
# Life Ladder (0 - 10): 7.28 :)
# GDP Per Capita (international dollars): 10.923 $$$$
# Social Support: 0.953
# Life Expectancy: 66.740
# Freedom: 0.878
# Generosity: 0.249
# Corruption: 0.668
#
# Country: Uruguay
# Year: 2008
# Life Ladder (0 - 10): 5.664 :|
# GDP Per Capita (international dollars): 9.769 $$$
# Social Support: 0.879
# Life Expectancy: 66.940
# Freedom: 0.808
# Generosity: -0.156
# Corruption: 0.597
#
# Country: Uzbekistan
# Year: 2008
# Life Ladder (0 - 10): 5.311 :|
# GDP Per Capita (international dollars): 8.402 $$$
# Social Support: 0.894
# Life Expectancy: 61.820
# Freedom: 0.831
# Generosity: -0.033
# Corruption:
#
# Country: Venezuela
# Year: 2008
# Life Ladder (0 - 10): 6.258 :)
# GDP Per Capita (international dollars): 9.719 $$$
# Social Support: 0.922
# Life Expectancy: 65.380
# Freedom: 0.678
# Generosity: -0.232
# Corruption: 0.776
#
# Country: Vietnam
# Year: 2008
# Life Ladder (0 - 10): 5.48 :|
# GDP Per Capita (international dollars): 8.658 $$$
# Social Support: 0.805
# Life Expectancy: 64.340
# Freedom: 0.889
# Generosity: 0.180
# Corruption: 0.789
#
# Country: Zambia
# Year: 2008
# Life Ladder (0 - 10): 4.73 :|
# GDP Per Capita (international dollars): 7.918 $$
# Social Support: 0.624
# Life Expectancy: 48.080
# Freedom: 0.717
# Generosity: 0.051
# Corruption: 0.890
#
# Country: Zimbabwe
# Year: 2008
# Life Ladder (0 - 10): 3.174 :(
# GDP Per Capita (international dollars): 7.21 $$
# Social Support: 0.843
# Life Expectancy: 42.800
# Freedom: 0.344
# Generosity: -0.077
# Corruption: 0.964

# %% [markdown]
# #Question 1

# %% [markdown]
# #Question 2

# %% [markdown]
# #Question 3

# %% [markdown]
# # Conclusion
# Reflection
